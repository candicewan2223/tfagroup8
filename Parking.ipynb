# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
df = pd.read_csv("311_Service_Requests_2020.csv")
df.head()
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    45285347  01/01/2020 12:00:00 AM  01/10/2020 12:00:01 AM  DOHMH
# 1    45285651  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 2    45285821  01/01/2020 12:00:00 AM  01/02/2020 09:50:09 AM  DOHMH
# 3    45287907  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
# 4    45288240  01/01/2020 12:00:00 AM  01/02/2020 12:00:01 AM  DOHMH
#
#                                Agency Name  Complaint Type Descriptor  \
# 0  Department of Health and Mental Hygiene  Food Poisoning  3 or More
# 1  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 2  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
# 3  Department of Health and Mental Hygiene  Food Poisoning  3 or More
# 4  Department of Health and Mental Hygiene  Food Poisoning     1 or 2
#
#                 Location Type  Incident Zip      Incident Address  ...  \
# ...

# %%
df1 = df[df["Incident Zip"] == 11101.0]
df1.head()
# Out:
#       Unique Key            Created Date             Closed Date Agency  \
# 760     45288823  01/01/2020 02:36:26 AM  01/01/2020 02:37:32 AM   NYPD
# 907     45285932  01/01/2020 03:14:55 AM  01/01/2020 05:07:22 PM   NYPD
# 919     45287793  01/01/2020 03:19:13 AM  01/01/2020 07:45:46 AM   NYPD
# 1257    45285116  01/01/2020 05:13:47 AM  01/01/2020 07:44:32 AM   NYPD
# 1748    45289554  01/01/2020 09:48:54 AM  01/01/2020 10:19:01 AM   NYPD
#
#                           Agency Name       Complaint Type        Descriptor  \
# 760   New York City Police Department  Noise - Residential   Loud Television
# 907   New York City Police Department         Animal-Abuse         Neglected
# 919   New York City Police Department  Noise - Residential  Loud Music/Party
# 1257  New York City Police Department   Noise - Commercial  Loud Music/Party
# 1748  New York City Police Department      Illegal Parking  Blocked Sidewalk
#
# ...

# %%
df2 = df1[df1["Complaint Type"] == "Illegal Parking"]
parking_counts_11101=df2['Complaint Type'].value_counts().astype(int)
parking_counts_11101 = parking_counts_11101.sum()
parking_counts_11101
# Out:
# 2982

# %%
incidents_counts_11101=df1['Complaint Type'].value_counts().astype(int)
incidents_counts_11101 = incidents_counts_11101.sum()
incidents_counts_11101
# Out:
# 17817

# %%
proportion_11101 = parking_counts_11101/incidents_counts_11101
proportion_11101
# Out:
# 0.1673682438120896

# %%
df3 = df[df["Complaint Type"] == "Illegal Parking"]
parking_counts = df3['Complaint Type'].value_counts().astype(int)
parking_counts = parking_counts.sum()
parking_counts
# Out:
# 193721

# %%
incidents_counts=df['Complaint Type'].value_counts().astype(int)
incidents_counts = incidents_counts.sum()
incidents_counts
# Out:
# 2587316

# %%
global_proportion = parking_counts/incidents_counts
global_proportion
# Out:
# 0.07487334365033108

# %%
if proportion_11101 > global_proportion:
    higher_parking_proportion = True
else:
    higher_parking_proportion = False

higher_parking_proportion
# Out:
# True

# %%
# Illegal parking incidents are a larger fraction of total 311 incidents in ZIP code 11101 than they are in general.
